# %% [markdown]
# # 🧪 Java Assignment: Comparing and Printing Monsters (Simplified)
#
# This project demonstrates how to use Java's `Comparable<T>` interface to compare and sort custom objects—in this case, Monsters—by their power level. It also includes a generic `Printer<T>` class to print object details in a reusable way.
#
# This exercise helps you practice how to:
#
# - Use **interfaces** (`Comparable`)
# - Sort custom objects (`Collections.sort`)
# - Create and use **generic classes**
# - Apply object-oriented principles
#
# ---
#
# ## 🔧 Part 0: Setup Your Workspace
#
# The code blocks below helpo you creating the desired scripts:
#
# - `Dragon.java`
# - `Goblin.java`
# - `Troll.java`
# - `Monster.java`
# - `MonsterArena.java`
# - `Printer.java`

# %%
# %%writefile Dragon.java
# /**
#  * Represents a monster with dragon qualities
#  */
#
# public class Dragon extends Monster {
#     public Dragon() {
#         super("Fire", 90);
#     }
# }
# Out:
# Overwriting Dragon.java

# %%
# %%writefile Goblin.java
# /**
#  * Represents a monster with goblin qualities
#  */
#
# public class Goblin extends Monster {
#     public Goblin() {
#         super("Earth", 30);
#     }
# }
# Out:
# Overwriting Goblin.java

# %%
# %%writefile Troll.java
# /**
#  * Represents a monster with troll qualities
#  */
#
#  public class Troll extends Monster {
#     public Troll() {
#         super("Rock", 50);
#     }
# }
# Out:
# Overwriting Troll.java

# %%
# %%writefile Monster.java
# /**
#  * Represents a monster with element and power level
#  */
#
# public abstract class Monster implements Comparable<Monster> {
#     protected String element;
#     protected int powerLevel;
#
#     public Monster(String element, int powerLevel) {
#         this.element = element;
#         this.powerLevel = powerLevel;
#     }
#
#     public String getElement() {
#         return element;
#     }
#
#     public int getPowerLevel() {
#         return powerLevel;
#     }
#
#     // TODO: Override the compareTo method
#     public int compareTo(Monster other) {
#         return Integer.compare(this.powerLevel, other.powerLevel);
#     }
#
#     // TODO: Override the toString method
#     public String toString() {
#         return "Type) " + this.getClass().getSimpleName() + "\nPower Level: " + this.powerLevel + "\nElement: " + this.element;
#     }
#
# }//class
# Out:
# Overwriting Monster.java

# %%
# %%writefile MonsterArena.java
# import java.util.ArrayList;
# import java.util.Collections;
# import java.util.Random;
#
# /**
#  * The MonsterArena class simulates an arena where different types of monsters
#  * are randomly created, sorted by power level, and printed before and after sorting.
#  * It demonstrates the use of the Comparable interface and Java generics.
#  */
# public class MonsterArena {
#
#     private ArrayList<Monster> monsterList = new ArrayList<>();
#
#     /**
#      * Initializes the arena by:
#      * - Creating 5 random Monster instances (Goblin, Dragon, or Troll)
#      * - Printing the list before sorting (using Printer<T>)
#      * - Sorting the monsters based on power level
#      * - Printing the list again after sorting
#      */
#     public void initializeMonsters() {
#         // Randomly generate 5 monsters
#         Random rand = new Random();
#
#         for (int i = 0; i < 5; i++) {
#             int choice = rand.nextInt(3); // Goblin, Dragon, Troll
#             Monster m;
#             if (choice == 0) {
#                 m = new Goblin();
#             } else if (choice == 1) {
#                 m = new Dragon();
#             } else {
#                 m = new Troll();
#             }
#             monsterList.add(m);
#         }
#
#
#         // TODO: Print before sorting
#        Printer<Monster> printer = new Printer<>(monsterList);
# printer.print();
#
#         // TODO: Sort monsters by powerLevel
#         Collections.sort(monsterList);
#
#         // TODO: Print after sorting
#         System.out.println("Updated:");
#         printer.print();
#     }
#
#     /**
#      * The main method to run the MonsterArena simulation.
#      * @param args command-line arguments (not used)
#     */
#     public static void main(String[] args) {
#         MonsterArena arena = new MonsterArena();
#         arena.initializeMonsters();
#     }
# }
# Out:
# Overwriting MonsterArena.java

# %%
# %%writefile Printer.java
# import java.util.ArrayList;
#
# public class Printer<T> {
#     private ArrayList<T> listRef;
#
#     public Printer(ArrayList<T> listRef) {
#         this.listRef = listRef;
#     }
#
#     public void print() {
#         for (T item : listRef) {
#             System.out.println(item);
#         }
#     }
# }
# Out:
# Overwriting Printer.java

# %% [markdown]
# ## 🧩 Part 1: Make Monsters Comparable
#
# ### Step 1: Update `Monster.java`
#
# - Add `implements Comparable<Monster>` to the class.
# - Implement the `compareTo(Monster other)` method using `powerLevel`.
# - Add print statements in `compareTo()` to see what's being compared.
# - Override `toString()` to include:
#   - Monster type
#   - Power level
#   - Element
#     Use `\n\t` to make it look nice.
#
# ### Step 2: Update `MonsterArena.java`
#
# - Review the code. It creates 5 random monsters.
# - Print the **unsorted list** using a `for` loop.
# - Sort the monsters:
#
# ```java
# Collections.sort(monsterList);
# ```
#
# - Print the **sorted list** using a loop.
#
# ---
#
# ## 💡 Part 2: Create a Generic Printer
#
# ### Step 1: Create `Printer.java`
#
# - Define a generic class:
#
# ```java
# public class Printer<T> {
#     private ArrayList<T> listRef;
#
#     public Printer(ArrayList<T> listRef) {
#         this.listRef = listRef;
#     }
#
#     public void print() {
#         for (T item : listRef) {
#             System.out.println(item);
#         }
#     }
# }
# ```
#
# ### Step 2: Use `Printer` in `MonsterArena.java`
#
# - Comment out your old `for`-loops.
# - Use the printer like this:
#
# ```java
# Printer<Monster> printer = new Printer<>(monsterList);
# printer.print();
# ```

# %%
# Compile your project and test it after following all the instructions above
# !javac *.java
# !java MonsterArena
# Out:
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Dragon
# Power Level: 90
# Element: Fire
# Type) Troll
# Power Level: 50
# Element: Rock
# Updated:
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Troll
# Power Level: 50
# Element: Rock
# Type) Dragon
# Power Level: 90
# Element: Fire

# %% [markdown]
# ## ✅ What You Learn
#
# These are the minimum concepts that you are learning in here:
#
# | Concept                 | Skill You Gain                    |
# | ----------------------- | --------------------------------- |
# | `Comparable<Monster>`   | Sorting custom objects            |
# | `compareTo()`           | Defining how objects are compared |
# | `Collections.sort()`    | Built-in sorting                  |
# | `toString()`            | Clear output for your class       |
# | Generics (`Printer<T>`) | Reusable code with any type       |
#
# ### Knowledge Checks
#
# You know that you are doing well when you can answer all of the follwoing questions:
#
# - What does implementing `Comparable<Monster>` allow your Monster class to do?
# - How does the `compareTo()` method determine which monster is stronger?
# - What would happen if you reversed the comparison logic in `compareTo()`?
# - Why do we override the `toString()` method in Java classes?
# - What is the purpose of using a generic class like `Printer<T>` instead of writing a MonsterPrinter?`
# - What are the advantages of using `Collections.sort() instead of writing your own sorting algorithm?
# - What did the debugging output inside `compareTo()` help you understand?
# - How could this approach to sorting and printing be applied in a different type of program (e.g., leaderboard, inventory list, student records)?
#
# ---
#
# Work together, share ideas, and submit individually. Happy coding! 🧙‍♂️

# %% [markdown]
# 1. Implementing Comparable<Monster> allows my Monster class to use the compare() method
# 2. compareTo() uses compare to scan two power levels, returning negative for stronger and posivites for weak
# 3. If compareTo() were to be reversed it would return positive for higher power levels rather than negative
# 4. We override the toString() as java inheirits by default to object adresses
# 4. Printer<t> creates methods that can be reused rather than a fixed MonsterPrinter
# 5. Collections.sort() is a default by java preventing errors that may come from building your own
# 6. Debug output helps understand the logic of compareTo()
# 7. The generic structures of compareTo(), Printer<T>, and Collections.sort() with arraylists can be replicated for different data sets
