# %% [markdown]
# # 🧪 Java Lab: Comparing and Printing Monsters
#
# This project demonstrates how to use Java's `Comparable<T>` interface to compare and sort custom objects—in this case, Monsters—by their power level. It also includes a generic `Printer<T>` class to print object details in a reusable way.
#
# This exercise helps you practice how to:
#
# - Use **interfaces** (`Comparable`)
# - Sort custom objects (`Collections.sort`)
# - Create and use **generic classes**
# - Apply object-oriented principles
#
# ---
#
# ## 🔧 Part 0: Setup Your Workspace
#
# The code blocks below create the Java source files for this lab. Run each one once to write the file to disk:
#
# - `Dragon.java`
# - `Goblin.java`
# - `Troll.java`
# - `Monster.java`
# - `MonsterArena.java`
# - `Printer.java`

# %%
# %%writefile Dragon.java
# /**
#  * Represents a monster with dragon qualities
#  */
#
# public class Dragon extends Monster {
#     public Dragon() {
#         super("Fire", 90);
#     }
# }
# Out:
# Overwriting Dragon.java

# %%
# %%writefile Goblin.java
# /**
#  * Represents a monster with goblin qualities
#  */
#
# public class Goblin extends Monster {
#     public Goblin() {
#         super("Earth", 30);
#     }
# }
# Out:
# Overwriting Goblin.java

# %%
# %%writefile Troll.java
# /**
#  * Represents a monster with troll qualities
#  */
#
#  public class Troll extends Monster {
#     public Troll() {
#         super("Rock", 50);
#     }
# }
# Out:
# Overwriting Troll.java

# %%
# %%writefile Monster.java
# /**
#  * Represents a monster with element and power level
#  */
#
# public abstract class Monster implements Comparable<Monster> {
#     protected String element;
#     protected int powerLevel;
#
#     public Monster(String element, int powerLevel) {
#         this.element = element;
#         this.powerLevel = powerLevel;
#     }
#
#     public String getElement() {
#         return element;
#     }
#
#     public int getPowerLevel() {
#         return powerLevel;
#     }
#
#     // TODO: Override the compareTo method
#     @Override
# public int compareTo(Monster other) {
#     return Integer.compare(this.powerLevel, other.powerLevel);
# }
#
#
#     // TODO: Override the toString method
#     @Override
# public String toString() {
#     return "Monster:\n\tElement: " + element + "\n\tPower Level: " + powerLevel;
# }
#
#
# }//class
# Out:
# Overwriting Monster.java

# %%
# %%writefile MonsterArena.java
# import java.util.ArrayList;
# import java.util.Collections;
# import java.util.Random;
#
# /**
#  * The MonsterArena class simulates an arena where different types of monsters
#  * are randomly created, sorted by power level, and printed before and after sorting.
#  * It demonstrates the use of the Comparable interface and Java generics.
#  */
# public class MonsterArena {
#
#     private ArrayList<Monster> monsterList = new ArrayList<>();
#
#     /**
#      * Initializes the arena by:
#      * - Creating 5 random Monster instances (Goblin, Dragon, or Troll)
#      * - Printing the list before sorting (using Printer<T>)
#      * - Sorting the monsters based on power level
#      * - Printing the list again after sorting
#      */
#     public void initializeMonsters() {
#         // Randomly generate 5 monsters
#         Random rand = new Random();
#
#         for (int i = 0; i < 5; i++) {
#             int choice = rand.nextInt(3); // Goblin, Dragon, Troll
#             Monster m;
#             if (choice == 0) {
#                 m = new Goblin();
#             } else if (choice == 1) {
#                 m = new Dragon();
#             } else {
#                 m = new Troll();
#             }
#             monsterList.add(m);
#         }
#
#
#         /**
#         // TODO: Print before sorting
#         System.out.println("Before sorting:");
#         Printer<Monster> printer = new Printer<>(monsterList);
#         printer.print();
#         // TODO: Sort monsters by powerLevel
#         Collections.sort(monsterList);
#         // TODO: Print after Sorting
#         System.out.println("After sorting:");
#         printer.print();
#         */
#
#         Printer<Monster> printer = new Printer<>(monsterList);
#         System.out.println("Monsters before sorting:");
#         printer.print();
#
#         Collections.sort(monsterList);
#
#         System.out.println();
#         System.out.println("Monsters after sorting by power level:");
#         printer.print();
#     }
#
#     /**
#      * The main method to run the MonsterArena simulation.
#      * @param args command-line arguments (not used)
#     */
#     public static void main(String[] args) {
#         MonsterArena arena = new MonsterArena();
#         arena.initializeMonsters();
#     }
# }
# Out:
# Overwriting MonsterArena.java

# %%
# %%writefile Printer.java
# //TODO: Implement the generic class Printer
# import java.util.ArrayList;
#
# public class Printer<T> {
#     private ArrayList<T> listRef;
#
#     public Printer(ArrayList<T> listRef) {
#         this.listRef = listRef;
#     }
#
#     public void print() {
#         for (T item : listRef) {
#             System.out.println(item);
#         }
#     }
# }
# Out:
# Overwriting Printer.java

# %% [markdown]
# ## 🧩 Part 1: Make Monsters Comparable
#
# ### Step 1: Update `Monster.java`
#
# - Add `implements Comparable<Monster>` to the class declaration.
# - Implement the `compareTo(Monster other)` method using `powerLevel`.
# - Override `toString()` to include:
#   - Monster type
#   - Element
#   - Power level
#
#   Use `\n\t` between the fields so the output is indented and easy to read.
# - Re-run the `Monster.java` cell so the file on disk reflects your edits.
#
# ### Step 2: Update `MonsterArena.java`
#
# - Review the code. It creates 5 random monsters.
# - Print the **unsorted list** using a `for` loop.
# - Sort the monsters:
#
# ```java
# Collections.sort(monsterList);
# ```
#
# - Print the **sorted list** using a loop.
#
# ---
#
# ## 💡 Part 2: Create a Generic Printer
#
# ### Step 1: Create `Printer.java`
#
# - Define a generic class:
#
# ```java
# import java.util.ArrayList;
#
# public class Printer<T> {
#     private ArrayList<T> listRef;
#
#     public Printer(ArrayList<T> listRef) {
#         this.listRef = listRef;
#     }
#
#     public void print() {
#         for (T item : listRef) {
#             System.out.println(item);
#         }
#     }
# }
# ```
#
# ### Step 2: Use `Printer` in `MonsterArena.java`
#
# - Comment out the old `for`-loops you wrote in Part 1.
# - Use the printer like this:
#
# ```java
# Printer<Monster> printer = new Printer<>(monsterList);
# printer.print();
# ```

# %%
# Compile your project and test it after following all the instructions above
# !javac *.java
# !java MonsterArena
# Out:
# Monsters before sorting:
# Monster:
# 	Element: Rock
# 	Power Level: 50
# Monster:
# 	Element: Fire
# 	Power Level: 90
# Monster:
# 	Element: Rock
# 	Power Level: 50
# Monster:
# 	Element: Fire
# 	Power Level: 90
# Monster:
# 	Element: Fire
# 	Power Level: 90
#
# Monsters after sorting by power level:
# Monster:
# 	Element: Rock
# 	Power Level: 50
# Monster:
# 	Element: Rock
# 	Power Level: 50
# Monster:
# 	Element: Fire
# 	Power Level: 90
# Monster:
# 	Element: Fire
# 	Power Level: 90
# Monster:
# 	Element: Fire
# 	Power Level: 90

# %% [markdown]
# ## ✅ What You Learn
#
# These are the minimum concepts that you are practicing here:
#
# | Concept                 | Skill You Gain                    |
# | ----------------------- | --------------------------------- |
# | `Comparable<Monster>`   | Sorting custom objects            |
# | `compareTo()`           | Defining how objects are compared |
# | `Collections.sort()`    | Built-in sorting                  |
# | `toString()`            | Clear output for your class       |
# | Generics (`Printer<T>`) | Reusable code with any type       |
#
# ### Knowledge Checks
#
# You are doing well when you can answer all of the following questions. Add a new markdown cell after each question and write your answer in English:
#
# 1. What does implementing `Comparable<Monster>` allow your `Monster` class to do?
# 2. How does the `compareTo()` method determine which monster is stronger?
# 3. What would happen if you reversed the comparison logic in `compareTo()`?
# 4. Why do we override the `toString()` method in Java classes?
# 5. What is the purpose of using a generic class like `Printer<T>` instead of writing a dedicated `MonsterPrinter`?
# 6. What are the advantages of using `Collections.sort()` instead of writing your own sorting algorithm?
# 7. What does the multi-line `toString()` output help you see about each monster?
# 8. How could this approach to sorting and printing be applied in a different type of program (e.g., leaderboard, inventory list, student records)?
#
# ---
#
# Work together, share ideas, and submit individually. Happy coding! 🧙‍♂️

# %% [markdown]
# 1. Implementing "Comparable< Monster >" allows my Monster class to edited by the compareTo() method
# 2. the compareTo() method determines who is stronger using their power level value to sort
# 3. If the comparison logic is reversed, other and this would be swapped, meaning positive returns are for less than rather than greater than
# 4. We override to annotate the creation of a body for toString(), that prevent errors from building up
# 5. Using a generic Printer< T > allows print method to be reused and edited by all the monsters classes (Troll, Dragon, and Goblin)
# 6. Collections.sort() is an easy built in sort rather writing your own, creating a potential error
# 7. toString() helps the user see info on the monster's power level and element
# 8. This approach can be applied to different programs as the ability to numerically sort data and apply elements to them is very versatile. Such as a leaderboard sorting by most completions, having elements like completion type/name
